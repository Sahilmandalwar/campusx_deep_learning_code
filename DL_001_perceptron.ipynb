# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahilmandalwar/campusx_deep_learning_code/blob/main/DL_001_perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/campusx-official/100-days-of-deep-learning/refs/heads/main/day3/placement.csv")

# %%
df.head(3)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1

# %%
from sklearn.linear_model import Perceptron

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split, cross_val_score
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
p = Perceptron()

# %%
p.fit(X_train,y_train)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[ 47.47, -38.37]])

# %%
p.intercept_
# Out:
# array([-32.])

# %%
pred = p.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(pred, y_test)
# Out:
# 0.6

# %%
np.mean(cross_val_score(p,X,y,scoring='accuracy',cv=10))
# Out:
# np.float64(0.5900000000000001)

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X.values,y.values,clf=p,legend=2)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
